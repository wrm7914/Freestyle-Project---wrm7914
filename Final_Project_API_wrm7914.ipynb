# %% [markdown]
# <a href="https://colab.research.google.com/github/wrm7914/Freestyle-Project---wrm7914/blob/main/Final_Project_API_wrm7914.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# []
# <class 'bs4.element.ResultSet'>

# %%
3002268b77f34516b264564454206216 ##

# %% [markdown]
# ### Requesting Data

# %%
## pip install requests
## !pip list

import os
import operator

import requests
import json
from getpass import getpass

## api_key = getpass("Please input your API key: ")
## 3002268b77f34516b264564454206216

api_key = "3002268b77f34516b264564454206216"

request_url = f"https://newsapi.org/v2/everything?q=keyword&apiKey={api_key}"

response = requests.get(request_url)

data = json.loads(response.text)
print(response.status_code)
print(type(data))
print(data)

print("---")

from pprint import pprint
# pprint(data)

print("---")

## print(type(response))

## print(dir(response))

for key in sorted(data):
  print(key, '->', data[key])

# for key in data.keys():
  #  print(key)

for item in data.items():
       print(item)
       print(type(item))

# print(len(data))

print("-----")
print(data["status"])

print(data["articles"])
print("-----")


article = data["articles"]
pprint(article)
# article_source = for key in sorted(data):
  # print(article_source)

# for v in data.values():
  # print(v)

# for item in data["source"]:
  # print(item, '->', data[item])


# for k, v in article_source.items():
  #  author = k[1]
   # description = v[1]
    # print(author/description)

# for k,v in data.items():
  # print(k)
  # print(v)
  # print("-----")

# for articles in data["status"]["description"]:
 #  print(data["author"], "...", data["url"])

# # print(data["author"]["title"])
## print("-----")


# for source in data["status"]
  #   print(data["status"])

## print(response.text)
## for data in response:
  ## print(data['status'])
# Out:
# 200
# <class 'dict'>
# ...
